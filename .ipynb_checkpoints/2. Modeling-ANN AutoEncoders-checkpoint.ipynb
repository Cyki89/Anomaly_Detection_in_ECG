# %% [markdown]
# ### 2.1 Import nessesary libraries and modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
import math
from sklearn.metrics import mean_absolute_error, accuracy_score
from tensorflow.compat.v1.keras.layers import Dense, Dropout, TimeDistributed, CuDNNLSTM, LSTM, RepeatVector

# %% [markdown]
# ## 2.2 Load the data

# %%
train_dataset = pd.read_csv("./data_preprocessed/train_dataset.csv", index_col=0)
val_dataset = pd.read_csv("./data_preprocessed/val_dataset.csv", index_col=0)
test_dataset = pd.read_csv("./data_preprocessed/test_dataset.csv", index_col=0)

# %%
train_dataset.head()
# Out:
#       timiestamp_1  timiestamp_2  timiestamp_3  timiestamp_4  timiestamp_5  \
# 1603      0.245897     -2.381731     -3.379114     -4.150560     -4.362152
# 3         0.545657     -1.014383     -2.316698     -3.634040     -4.196857
# 2553      0.070699     -2.856309     -4.265050     -4.404080     -4.180707
# 269      -1.537689     -2.534511     -4.240574     -5.250626     -4.853930
# 286      -0.296967     -2.149871     -3.835708     -4.670072     -4.334111
#
#       timiestamp_6  timiestamp_7  timiestamp_8  timiestamp_9  timiestamp_10  \
# 1603     -3.604735     -2.203830     -1.692911     -1.411593      -0.453160
# 3        -3.758093     -3.194444     -2.221764     -1.588554      -1.202146
# 2553     -3.840098     -2.526704     -1.319836     -1.181694      -0.682616
# 269      -4.223230     -3.200279     -2.332330     -1.817484      -1.083945
# 286      -3.239545     -2.080338     -1.665445     -1.266009      -0.374374
#
#       ...  timiestamp_132  timiestamp_133  timiestamp_134  timiestamp_135  \
# 1603  ...        0.801240        0.956382        1.052721        1.283904
# 3     ...        0.777530        1.119240        0.902984        0.554098
# 2553  ...        1.168188        1.352643        1.585120        1.585385
# 269   ...       -0.032903        0.299982        0.707729        0.908099
# 286   ...        0.800871        1.086116        1.090475        0.898527
#
#       timiestamp_136  timiestamp_137  timiestamp_138  timiestamp_139  \
# 1603        1.140007        1.142146        0.833684        1.462835
# 3           0.497053        0.418116        0.703108        1.064602
# 2553        1.309638        1.017802        0.896873        1.368133
# 269         1.004647        0.855263        0.383952        0.890997
# 286         0.860276        1.536581        1.852604        0.618098
#
#       timiestamp_140  label
# 1603        1.532836      1
# 3          -0.044853      1
# 2553       -0.049731      1
# 269         0.461981      1
# 286        -2.105530      1
#
# [5 rows x 141 columns]

# %% [markdown]
# ## 2.3 Transform data for LSTM AutoEncoder

# %% [markdown]
# ### 2.3.1 Drop labels from training set and convert dataframe to numpy array

# %%
X_train = np.array(train_dataset.drop(columns=['label']))
print(X_train.shape)
# Out:
# (2481, 140)

# %% [markdown]
# ### 2.3.2 Split test and validation dataset to feature and labels sets

# %%
X_val, y_val = np.array(val_dataset.drop(columns=['label'])), np.array(val_dataset['label'])
X_test, y_test = np.array(test_dataset.drop(columns=['label'])), np.array(test_dataset['label'])

print(X_val.shape, y_val.shape, X_test.shape, y_test.shape)
# Out:
# (438, 140) (438,) (438, 140) (438,)

# %% [markdown]
# ### 2.4 ANN AutoEncoder with only one hidden layer

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
import math
from sklearn.metrics import mean_absolute_error
from tensorflow.compat.v1.keras.layers import Dense, Dropout, TimeDistributed, CuDNNLSTM, LSTM, RepeatVector

# %%
# define early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='loss', 
    min_delta=0, # minimum change to 
    verbose=1,
    patience=20,
    mode='min',
    baseline=None,
    restore_best_weights=True)

# Build model
model = Sequential()
model.add(Dense(units=128, input_shape=(X_train.shape[1:]), activation='relu') )
model.add(Dense(units=32) )
model.add(Dense(units=128, activation='relu') )
model.add(Dense(units=X_train.shape[1]) )
model.compile(loss='mae', optimizer='adam')
model.summary()

# fit network
history=model.fit(X_train, X_train, epochs=100, batch_size=32, verbose=1, callbacks=[early_stopping])

# print training history
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss'], label='validation')
plt.legend()
plt.show()
print()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               18048
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dense_3 (Dense)              (None, 140)               18060
# =================================================================
# Total params: 44,460
# Trainable params: 44,460
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2481 samples
# Epoch 1/100
# 2481/2481 [==============================] - 1s 374us/sample - loss: 0.3191
# Epoch 2/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.1569
# Epoch 3/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.1250
# Epoch 4/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.1036
# Epoch 5/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0940
# Epoch 6/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0880
# Epoch 7/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0841
# Epoch 8/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0810
# Epoch 9/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0782
# Epoch 10/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0760
# Epoch 11/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0738
# Epoch 12/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0730
# Epoch 13/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0712
# Epoch 14/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0698
# Epoch 15/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0687
# Epoch 16/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0675
# Epoch 17/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0669
# Epoch 18/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0661
# Epoch 19/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0656
# Epoch 20/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0642
# Epoch 21/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0639
# Epoch 22/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0631
# Epoch 23/100
# 2481/2481 [==============================] - 0s 89us/sample - loss: 0.0627
# Epoch 24/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0622
# Epoch 25/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0614
# Epoch 26/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0610
# Epoch 27/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0601
# Epoch 28/100
# 2481/2481 [==============================] - 0s 86us/sample - loss: 0.0602
# Epoch 29/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0598
# Epoch 30/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0592
# Epoch 31/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0589
# Epoch 32/100
# 2481/2481 [==============================] - 0s 90us/sample - loss: 0.0585
# Epoch 33/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0579
# Epoch 34/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0581
# Epoch 35/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0576
# Epoch 36/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0572
# Epoch 37/100
# 2481/2481 [==============================] - 0s 91us/sample - loss: 0.0568
# Epoch 38/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0563
# Epoch 39/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0560
# Epoch 40/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0560
# Epoch 41/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0560
# Epoch 42/100
# 2481/2481 [==============================] - 0s 86us/sample - loss: 0.0556
# Epoch 43/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0556
# Epoch 44/100
# 2481/2481 [==============================] - 0s 89us/sample - loss: 0.0551
# Epoch 45/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0550
# Epoch 46/100
# 2481/2481 [==============================] - 0s 90us/sample - loss: 0.0547
# Epoch 47/100
# 2481/2481 [==============================] - 0s 84us/sample - loss: 0.0547
# Epoch 48/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0544
# Epoch 49/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0540
# Epoch 50/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0538
# Epoch 51/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0538
# Epoch 52/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0538
# Epoch 53/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0535
# Epoch 54/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0530
# Epoch 55/100
# 2481/2481 [==============================] - 0s 92us/sample - loss: 0.0528
# Epoch 56/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0529
# Epoch 57/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0527
# Epoch 58/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0529
# Epoch 59/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0528
# Epoch 60/100
# 2481/2481 [==============================] - 0s 92us/sample - loss: 0.0526
# Epoch 61/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0520
# Epoch 62/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0524
# Epoch 63/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0523
# Epoch 64/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0518
# Epoch 65/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0518
# Epoch 66/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0515
# Epoch 67/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0517
# Epoch 68/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0512
# Epoch 69/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0515
# Epoch 70/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0509
# Epoch 71/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0509
# Epoch 72/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0507
# Epoch 73/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0505
# Epoch 74/100
# 2481/2481 [==============================] - 0s 92us/sample - loss: 0.0502
# Epoch 75/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0509
# Epoch 76/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0507
# Epoch 77/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0502
# Epoch 78/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0507
# Epoch 79/100
# 2481/2481 [==============================] - 0s 86us/sample - loss: 0.0498
# Epoch 80/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0498
# Epoch 81/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0499
# Epoch 82/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0495
# Epoch 83/100
# 2481/2481 [==============================] - 0s 91us/sample - loss: 0.0500
# Epoch 84/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0497
# Epoch 85/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0493
# Epoch 86/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0495
# Epoch 87/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0492
# Epoch 88/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0493
# Epoch 89/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0491
# Epoch 90/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0491
# Epoch 91/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0493
# Epoch 92/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0486
# Epoch 93/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0485
# Epoch 94/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0488
# Epoch 95/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0487
# Epoch 96/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0483
# Epoch 97/100
# 2481/2481 [==============================] - 0s 91us/sample - loss: 0.0484
# Epoch 98/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0481
# Epoch 99/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0486
# Epoch 100/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0485

# %%
# make prediction on training set
X_train_pred = model.predict(X_train)
print(X_train_pred.shape)

# plot baseline and predictions
for i in range(10):
    plt.figure(figsize=(15,5))
    plt.plot(X_train[i].flatten(), color='g', label='true')
    plt.plot(X_train_pred[i].flatten(), color='r', label='predicted')
    plt.legend()
    plt.show()
    print()
# Out:
# (2481, 140)

# %%
# make prediction(reconstruction) training set
X_train_pred = model.predict(X_train)

# make prediction(reconstruction) validation set
X_val_pred = model.predict(X_val)

# make prediction(reconstruction) test set
X_test_pred = model.predict(X_test)

# calculate reconstrucion loss for each train sequence
train_loss = [mean_absolute_error( X_train[i].flatten(), X_train_pred[i].flatten() ) for i in range(X_train.shape[0])]

# calculate reconstrucion loss for each val sequence
val_loss = [mean_absolute_error( X_val[i].flatten(), X_val_pred[i].flatten() ) for i in range(X_val.shape[0])]

# calculate reconstrucion loss for each test sequence
test_loss = [mean_absolute_error( X_test[i].flatten(), X_test_pred[i].flatten() ) for i in range(X_test.shape[0])]

# show train reconstrucion losses distribution
sns.distplot(train_loss, bins=50, kde=True);

# %%
# define percentile range for tesing threshold
percentiles = range(90,100)

# define threshold variable
THRESHOLD = None
best_accuracy = 0

for percentile in percentiles:
    # set theshold based on percentile on train reconctrucion losses
    testing_threshold = np.percentile(train_loss, percentile)
    
    # predict validation set classes based on validation reconctrucion losses and testing threshold
    y_val_pred= [int(x < testing_threshold) for x in val_loss]
    y_test_pred = [int(x < testing_threshold) for x in test_loss]
    
    # calculate validaion accuracy
    val_accuracy = accuracy_score(y_val_pred, y_val)
    test_accuracy = accuracy_score(y_test_pred, y_test)
    
    # compare current validation accuracy with best accuracy
    if val_accuracy > best_accuracy:
        best_accuracy = val_accuracy
        THRESHOLD = testing_threshold
    
    print((f'Perentile:{percentile} | Threshold: {round(testing_threshold,4)} ' 
           f'| Val Accuracy: {round(val_accuracy, 4)} | '
           f'Test Accuracy: {round(test_accuracy ,4)} ') )

print('-'*50)
print(f'Best validation accuracy: {round(best_accuracy,4)} for Threshold {round(THRESHOLD,4)}')
# Out:
# Perentile:90 | Threshold: 0.0621 | Val Accuracy: 0.9429 | Test Accuracy: 0.9132
# Perentile:91 | Threshold: 0.0644 | Val Accuracy: 0.9452 | Test Accuracy: 0.9247
# Perentile:92 | Threshold: 0.0667 | Val Accuracy: 0.9498 | Test Accuracy: 0.9292
# Perentile:93 | Threshold: 0.0692 | Val Accuracy: 0.9612 | Test Accuracy: 0.9361
# Perentile:94 | Threshold: 0.0735 | Val Accuracy: 0.9635 | Test Accuracy: 0.9429
# Perentile:95 | Threshold: 0.0778 | Val Accuracy: 0.9703 | Test Accuracy: 0.9429
# Perentile:96 | Threshold: 0.085 | Val Accuracy: 0.9726 | Test Accuracy: 0.9475
# Perentile:97 | Threshold: 0.0941 | Val Accuracy: 0.9772 | Test Accuracy: 0.9566
# Perentile:98 | Threshold: 0.1093 | Val Accuracy: 0.9817 | Test Accuracy: 0.9726
# Perentile:99 | Threshold: 0.1638 | Val Accuracy: 0.895 | Test Accuracy: 0.8973
# --------------------------------------------------
# Best validation accuracy: 0.9817 for Threshold 0.1093

# %%
# predict test set classes based on test reconctrucion losses and selected threshold
y_test_pred = [int(x < THRESHOLD) for x in test_loss]

# calculate test set accuracy prediction
test_accuracy = accuracy_score(y_test_pred, y_test)

print(round(test_accuracy,4))
# Out:
# 0.9726

# %%
def plot_prediction(data, model, title, ax):
    predictions = model.predict(data)
    pred_losses = mean_absolute_error(predictions.flatten(), data.flatten())
    ax.plot(data.flatten(), label='true')
    ax.plot(predictions.flatten(), label='reconstructed')
    ax.set_title(f'{title} (loss: {np.around(pred_losses, 2)})')
    ax.legend()

# %%
# plot some  normal and anomaly sample prediction from test set
X_test_normal = X_test[y_test==1]
X_test_anomaly = X_test[y_test==0]


fig, axs = plt.subplots(
  nrows=2,
  ncols=6,
  sharey=True,
  sharex=True,
  figsize=(22, 8)
)

for i in range(6):
    plot_prediction(X_test_normal[i:i+1], model, title='Normal', ax=axs[0, i])

for i in range(6):
    plot_prediction(X_test_anomaly[i:i+1], model, title='Anomaly', ax=axs[1, i])

fig.tight_layout();

# %% [markdown]
# ### 2.3.4 Scaling data with MinMaxScaler(0,1)

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler, StandardScaler

class MultipleColumnScaler(BaseEstimator, TransformerMixin):
    ''' take multiple columns and scaling it's keeping original ratio between them '''
    def __init__(self, scaler):
        self.scaler = scaler
        
    def fit(self, X, y=None):
        columns_merged = X[:,0]
        for i in range(1, X.shape[1]):
            columns_merged = np.concatenate((columns_merged, X[:,i]), axis=0)
        self.scaler.fit(columns_merged.reshape(-1,1))
        return self.scaler
    
    def transform(self, X, y=None):
        X_new = self.scaler.transform(X[:, 0].reshape(-1,1))
        for i in range(1, X.shape[1]):
            X_curr = self.scaler.transform(X[:, i].reshape(-1,1))
            X_new = np.concatenate((X_new, X_curr), axis=1)
        return X_new

# %%
X_train = np.array(train_dataset.drop(columns=['label']))
print(X_train.shape)

X_val, y_val = np.array(val_dataset.drop(columns=['label'])), np.array(val_dataset['label'])
X_test, y_test = np.array(test_dataset.drop(columns=['label'])), np.array(test_dataset['label'])

print(X_val.shape, y_val.shape, X_test.shape, y_test.shape)

X_scaler = MultipleColumnScaler(MinMaxScaler(feature_range=(0,1) ) )
X_scaler = X_scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_val_scaled = X_scaler.transform(X_val)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# (2481, 140)
# (438, 140) (438,) (438, 140) (438,)

# %%
# define early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='loss', 
    min_delta=0, # minimum change to 
    verbose=1,
    patience=20,
    mode='min',
    baseline=None,
    restore_best_weights=True)

# Build model
model = Sequential()
model.add(Dense(units=128, input_shape=(X_train_scaled.shape[1:]), activation='relu') )
model.add(Dense(units=32) )
model.add(Dense(units=128, activation='relu') )
model.add(Dense(units=X_train_scaled.shape[1]) )
model.compile(loss='mae', optimizer='adam')
model.summary()

# fit network
history=model.fit(X_train_scaled, X_train_scaled, epochs=100, batch_size=32, verbose=1, callbacks=[early_stopping])

# print training history
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss'], label='validation')
plt.legend()
plt.show()
print()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               18048
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dense_7 (Dense)              (None, 140)               18060
# =================================================================
# Total params: 44,460
# Trainable params: 44,460
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2481 samples
# Epoch 1/100
# 2481/2481 [==============================] - 0s 201us/sample - loss: 0.1009
# Epoch 2/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0242
# Epoch 3/100
# 2481/2481 [==============================] - 0s 93us/sample - loss: 0.0225
# Epoch 4/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0209
# Epoch 5/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0196
# Epoch 6/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0185
# Epoch 7/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0172
# Epoch 8/100
# 2481/2481 [==============================] - 0s 91us/sample - loss: 0.0163
# Epoch 9/100
# 2481/2481 [==============================] - 0s 104us/sample - loss: 0.0163
# Epoch 10/100
# 2481/2481 [==============================] - 0s 94us/sample - loss: 0.0157
# Epoch 11/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0146
# Epoch 12/100
# 2481/2481 [==============================] - 0s 99us/sample - loss: 0.0141
# Epoch 13/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0136
# Epoch 14/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0133
# Epoch 15/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0125
# Epoch 16/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0123
# Epoch 17/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0121
# Epoch 18/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0119
# Epoch 19/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0117
# Epoch 20/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0113
# Epoch 21/100
# 2481/2481 [==============================] - 0s 89us/sample - loss: 0.0112
# Epoch 22/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0110
# Epoch 23/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0107
# Epoch 24/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0108
# Epoch 25/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0109
# Epoch 26/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0105
# Epoch 27/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0103
# Epoch 28/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0102
# Epoch 29/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0103
# Epoch 30/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0100
# Epoch 31/100
# 2481/2481 [==============================] - 0s 92us/sample - loss: 0.0102
# Epoch 32/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0101
# Epoch 33/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0098
# Epoch 34/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0098
# Epoch 35/100
# 2481/2481 [==============================] - 0s 90us/sample - loss: 0.0096
# Epoch 36/100
# 2481/2481 [==============================] - 0s 83us/sample - loss: 0.0092
# Epoch 37/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0093
# Epoch 38/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0101
# Epoch 39/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0107
# Epoch 40/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0090
# Epoch 41/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0089
# Epoch 42/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0089
# Epoch 43/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0089
# Epoch 44/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0087
# Epoch 45/100
# 2481/2481 [==============================] - 0s 86us/sample - loss: 0.0086
# Epoch 46/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0089
# Epoch 47/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0088
# Epoch 48/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0097
# Epoch 49/100
# 2481/2481 [==============================] - 0s 95us/sample - loss: 0.0086
# Epoch 50/100
# 2481/2481 [==============================] - 0s 90us/sample - loss: 0.0085
# Epoch 51/100
# 2481/2481 [==============================] - 0s 91us/sample - loss: 0.0086
# Epoch 52/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0086
# Epoch 53/100
# 2481/2481 [==============================] - 0s 87us/sample - loss: 0.0085
# Epoch 54/100
# 2481/2481 [==============================] - 0s 90us/sample - loss: 0.0084
# Epoch 55/100
# 2481/2481 [==============================] - 0s 100us/sample - loss: 0.0087
# Epoch 56/100
# 2481/2481 [==============================] - 0s 98us/sample - loss: 0.0083
# Epoch 57/100
# 2481/2481 [==============================] - 0s 90us/sample - loss: 0.0083
# Epoch 58/100
# 2481/2481 [==============================] - 0s 90us/sample - loss: 0.0081
# Epoch 59/100
# 2481/2481 [==============================] - 0s 84us/sample - loss: 0.0080
# Epoch 60/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0087
# Epoch 61/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0085
# Epoch 62/100
# 2481/2481 [==============================] - 0s 93us/sample - loss: 0.0078
# Epoch 63/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0078
# Epoch 64/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0078
# Epoch 65/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0083
# Epoch 66/100
# 2481/2481 [==============================] - 0s 82us/sample - loss: 0.0084
# Epoch 67/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0078
# Epoch 68/100
# 2481/2481 [==============================] - 0s 97us/sample - loss: 0.0076
# Epoch 69/100
# 2481/2481 [==============================] - 0s 85us/sample - loss: 0.0077
# Epoch 70/100
# 2481/2481 [==============================] - 0s 94us/sample - loss: 0.0076
# Epoch 71/100
# 2481/2481 [==============================] - 0s 106us/sample - loss: 0.0079
# Epoch 72/100
# 2481/2481 [==============================] - 0s 110us/sample - loss: 0.0081
# Epoch 73/100
# 2481/2481 [==============================] - 0s 94us/sample - loss: 0.0075
# Epoch 74/100
# 2481/2481 [==============================] - 0s 98us/sample - loss: 0.0075
# Epoch 75/100
# 2481/2481 [==============================] - 0s 110us/sample - loss: 0.0076
# Epoch 76/100
# 2481/2481 [==============================] - 0s 115us/sample - loss: 0.0079
# Epoch 77/100
# 2481/2481 [==============================] - 0s 119us/sample - loss: 0.0074
# Epoch 78/100
# 2481/2481 [==============================] - 0s 107us/sample - loss: 0.0075
# Epoch 79/100
# 2481/2481 [==============================] - 0s 108us/sample - loss: 0.0076
# Epoch 80/100
# 2481/2481 [==============================] - 0s 109us/sample - loss: 0.0075
# Epoch 81/100
# 2481/2481 [==============================] - 0s 99us/sample - loss: 0.0076
# Epoch 82/100
# 2481/2481 [==============================] - 0s 99us/sample - loss: 0.0075
# Epoch 83/100
# 2481/2481 [==============================] - 0s 102us/sample - loss: 0.0077
# Epoch 84/100
# 2481/2481 [==============================] - 0s 94us/sample - loss: 0.0076
# Epoch 85/100
# 2481/2481 [==============================] - 0s 101us/sample - loss: 0.0075
# Epoch 86/100
# 2481/2481 [==============================] - 0s 92us/sample - loss: 0.0073
# Epoch 87/100
# 2481/2481 [==============================] - 0s 97us/sample - loss: 0.0075
# Epoch 88/100
# 2481/2481 [==============================] - 0s 86us/sample - loss: 0.0073
# Epoch 89/100
# 2481/2481 [==============================] - 0s 93us/sample - loss: 0.0075
# Epoch 90/100
# 2481/2481 [==============================] - 0s 94us/sample - loss: 0.0071
# Epoch 91/100
# 2481/2481 [==============================] - 0s 94us/sample - loss: 0.0076
# Epoch 92/100
# 2481/2481 [==============================] - 0s 110us/sample - loss: 0.0072
# Epoch 93/100
# 2481/2481 [==============================] - 0s 97us/sample - loss: 0.0074
# Epoch 94/100
# 2481/2481 [==============================] - 0s 91us/sample - loss: 0.0074
# Epoch 95/100
# 2481/2481 [==============================] - 0s 94us/sample - loss: 0.0073
# Epoch 96/100
# 2481/2481 [==============================] - 0s 91us/sample - loss: 0.0072
# Epoch 97/100
# 2481/2481 [==============================] - 0s 94us/sample - loss: 0.0074
# Epoch 98/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0073
# Epoch 99/100
# 2481/2481 [==============================] - 0s 88us/sample - loss: 0.0072
# Epoch 100/100
# 2481/2481 [==============================] - 0s 108us/sample - loss: 0.0073

# %%
# make prediction on training set
X_train_scaled_pred = model.predict(X_train_scaled)

# inverse scaling
X_train_inv_pred = X_scaler.inverse_transform(X_train_scaled)

# plot baseline and predictions
for i in range(10):
    plt.figure(figsize=(15,5))
    plt.plot(X_train[i].flatten(), color='g', label='true')
    plt.plot(X_train_inv_pred[i].flatten(), color='r', label='predicted')
    plt.legend()
    plt.show()
    print()

# %%
# make prediction(reconstruction) training set
X_train_pred = model.predict(X_train_scaled)

# make prediction(reconstruction) validation set
X_val_pred = model.predict(X_val_scaled)

# make prediction(reconstruction) test set
X_test_pred = model.predict(X_test_scaled)

# inverse scaling 
X_train_pred = X_scaler.inverse_transform(X_train_pred)
X_val_pred = X_scaler.inverse_transform(X_val_pred)
X_test_pred = X_scaler.inverse_transform(X_test_pred)

# calculate reconstrucion loss for each train sequence
train_loss = [mean_absolute_error( X_train[i].flatten(), X_train_pred[i].flatten() ) for i in range(X_train.shape[0])]

# calculate reconstrucion loss for each val sequence
val_loss = [mean_absolute_error( X_val[i].flatten(), X_val_pred[i].flatten() ) for i in range(X_val.shape[0])]

# calculate reconstrucion loss for each test sequence
test_loss = [mean_absolute_error( X_test[i].flatten(), X_test_pred[i].flatten() ) for i in range(X_test.shape[0])]

# show train reconstrucion losses distribution
sns.distplot(train_loss, bins=50, kde=True);

# %%
# define percentile range for tesing threshold
percentiles = range(90,100)

# define threshold variable
THRESHOLD = None
best_accuracy = 0

for percentile in percentiles:
    # set theshold based on percentile on train reconctrucion losses
    testing_threshold = np.percentile(train_loss, percentile)
    
    # predict validation set classes based on validation reconctrucion losses and testing threshold
    y_val_pred= [int(x < testing_threshold) for x in val_loss]
    y_test_pred = [int(x < testing_threshold) for x in test_loss]
    
    # calculate validaion accuracy
    val_accuracy = accuracy_score(y_val_pred, y_val)
    test_accuracy = accuracy_score(y_test_pred, y_test)
    
    # compare current validation accuracy with best accuracy
    if val_accuracy > best_accuracy:
        best_accuracy = val_accuracy
        THRESHOLD = testing_threshold
    
    print((f'Perentile:{percentile} | Threshold: {round(testing_threshold,4)} ' 
           f'| Val Accuracy: {round(val_accuracy, 4)} | '
           f'Test Accuracy: {round(test_accuracy ,4)} ') )

print('-'*50)
print(f'Best validation accuracy: {round(best_accuracy,4)} for Threshold {round(THRESHOLD,4)}')
# Out:
# Perentile:90 | Threshold: 0.1236 | Val Accuracy: 0.9612 | Test Accuracy: 0.9247
# Perentile:91 | Threshold: 0.1272 | Val Accuracy: 0.9658 | Test Accuracy: 0.9315
# Perentile:92 | Threshold: 0.1313 | Val Accuracy: 0.9658 | Test Accuracy: 0.9429
# Perentile:93 | Threshold: 0.1369 | Val Accuracy: 0.9658 | Test Accuracy: 0.9498
# Perentile:94 | Threshold: 0.1437 | Val Accuracy: 0.9703 | Test Accuracy: 0.9589
# Perentile:95 | Threshold: 0.1521 | Val Accuracy: 0.9635 | Test Accuracy: 0.9658
# Perentile:96 | Threshold: 0.1656 | Val Accuracy: 0.9612 | Test Accuracy: 0.9566
# Perentile:97 | Threshold: 0.1854 | Val Accuracy: 0.911 | Test Accuracy: 0.9018
# Perentile:98 | Threshold: 0.2145 | Val Accuracy: 0.7557 | Test Accuracy: 0.7237
# Perentile:99 | Threshold: 0.2581 | Val Accuracy: 0.5936 | Test Accuracy: 0.589
# --------------------------------------------------
# Best validation accuracy: 0.9703 for Threshold 0.1437

# %%
# predict test set classes based on test reconctrucion losses and selected threshold
y_test_pred = [int(x < THRESHOLD) for x in test_loss]

# calculate test set accuracy prediction
test_accuracy = accuracy_score(y_test_pred, y_test)

print(round(test_accuracy,4))
# Out:
# 0.9589

# %%
def plot_prediction(data, data_scaled, X_scaler, model, title, ax):
    predictions = model.predict(data_scaled)
    predictions = X_scaler.inverse_transform(predictions.reshape(predictions.shape[:2]))
    pred_losses = mean_absolute_error(predictions.flatten(), data.flatten())
    ax.plot(data.flatten(), label='true')
    ax.plot(predictions.flatten(), label='reconstructed')
    ax.set_title(f'{title} (loss: {np.around(pred_losses, 2)})')
    ax.legend()

# %%
# plot some  normal and anomaly sample prediction from test set
X_test_normal_scaled = X_test_scaled[y_test==1]
X_test_anomaly_scaled = X_test_scaled[y_test==0]
X_test_normal = X_test[y_test==1]
X_test_anomaly = X_test[y_test==0]

fig, axs = plt.subplots(
  nrows=2,
  ncols=6,
  sharey=True,
  sharex=True,
  figsize=(22, 8)
)

for i in range(6):
    plot_prediction(X_test_normal[i:i+1], X_test_normal_scaled[i:i+1], X_scaler, model, title='Normal', ax=axs[0, i])

for i in range(6):
    plot_prediction(X_test_anomaly[i:i+1], X_test_anomaly_scaled[i:i+1], X_scaler, model, title='Anomaly', ax=axs[1, i])

fig.tight_layout();
